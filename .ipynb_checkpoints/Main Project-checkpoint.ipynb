# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import calendar

# %%
customers={
    'customer_id':np.arange(1,201),
    'age':np.random.randint(18, 40, 200),
    'gender':np.random.choice(['Male', 'Female'], 200),
    'city':np.random.choice(['Mumbai', 'Pune', 'Lucknow', 'Jaipur', 'Surat', 'Bhopal', 'Indore'], 200),
}
months=list(calendar.month_name)[1:]
df1=pd.DataFrame(customers)

# %%
orders={
    'order_id':np.arange(1, 1001),
    'customer_id':np.random.choice(customers['customer_id'], 1000),
    'prod_category':np.random.choice(['elec', 'toy', 'beauty'], 1000),
    'quantity':np.random.randint(1,10, 1000),
    'price':np.random.randint(699, 2999, 1000),
    'order_month':np.random.choice(months, 1000)
}
df2=pd.DataFrame(orders)

# %%
products={
    'prod_category':['elec', 'toy', 'beauty'],
    'profit_margin':[0.25, 0.40, 0.5]
}
df3=pd.DataFrame(products)

# %%
df4=pd.merge(df1, df2)

# %%
dff=pd.merge(df3, df4)
dff
# Out:
#     prod_category  profit_margin  customer_id  age  gender    city  order_id  \
# 0            elec           0.25            1   28    Male    Pune       862
# 1            elec           0.25            3   23  Female  Jaipur       643
# 2            elec           0.25            6   25    Male  Indore       352
# 3            elec           0.25            8   21    Male    Pune       186
# 4            elec           0.25            9   26    Male  Indore       491
# ..            ...            ...          ...  ...     ...     ...       ...
# 995        beauty           0.50          193   27  Female    Pune       975
# 996        beauty           0.50          194   39  Female    Pune        60
# 997        beauty           0.50          196   38    Male  Bhopal       998
# 998        beauty           0.50          198   39  Female    Pune       325
# 999        beauty           0.50          200   30    Male  Jaipur       510
#
#      quantity  price order_month
# 0           8   1566        July
# 1           1   2512        June
# 2           9    838     October
# 3           5   1530       March
# 4           4   2437    February
# ..        ...    ...         ...
# 995         4   2898     October
# 996         8   2304       March
# 997         6   2949        June
# 998         7   1780        July
# 999         9   1448     October
#
# [1000 rows x 10 columns]

# %%
dff.to_csv('ecommerce_data.csv', index=False)
